# %% [markdown]
# <a href="https://colab.research.google.com/github/valmirdev/Fundamentos-da-Linguagem-Python/blob/main/010_Utilizando_a_t%C3%A9cnica_de_slicing_em_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Slicing (fatiamento)
#
# A técnica de fatiamento nos permite acessar partes de uma string utilizando a notação de índice.

# %% [markdown]
# ## Acessando o índice

# %%
frase = 'Meu nome é Vinicius e eu estou estudando Python.'

# %%
frase[0]
# Out:
# 'M'

# %%
frase[11]
# Out:
# 'V'

# %% [markdown]
# ## Notação de dois pontos

# %%
frase[0:3]
# Out:
# 'Meu'

# %%
frase[11:19]
# Out:
# 'Vinicius'

# %%
frase[11:]
# Out:
# 'Vinicius e eu estou estudando Python.'

# %%
frase[:]
# Out:
# 'Meu nome é Vinicius e eu estou estudando Python.'

# %%
print(frase)
# Out:
# Meu nome é Vinicius e eu estou estudando Python.

# %%
frase[-7:]
# Out:
# 'Python.'

# %% [markdown]
# ## Steps (passos)

# %%
print(frase)
# Out:
# Meu nome é Vinicius e eu estou estudando Python.

# %%
frase[0:19:4]
# Out:
# 'Mn ii'

# %% [markdown]
# ## Invertendo uma string com slicing

# %%
frase[::-1]
# Out:
# '.nohtyP odnadutse uotse ue e suiciniV é emon ueM'
