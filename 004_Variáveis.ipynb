# %% [markdown]
# <a href="https://colab.research.google.com/github/valmirdev/Fundamentos-da-Linguagem-Python/blob/main/004_Vari%C3%A1veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # O que são variáveis?
#
# Variáveis são um dos recursos mais básicos das linguagens de programação.
#
# Através da utilização de variáveis, podemos armazenar dados na memória do computador para acessá-los mais tarde, quando forem necessários.

# %% [markdown]
# # Declaração e atribuição
#
# Algumas regras devem ser seguidas ao criarmos um nome para uma variável:
#
# - precisa começar com uma letra ou um underscore
# - não pode começar com um número
# - não pode conter caracteres especiais (*, $, %, #, @...etc...)
# - nomes de variáveis são case sensitives (`nome` é diferente de `Nome`)
# - não pode ser uma palavra reservada da linguagem
#
# ![palavras_reservadas.png](data:image/png;base64,...)

# %%
nome_aluno = 'Vinicius'

# %%
print(nome_aluno)
# Out:
# Vinicius

# %%
numero01 = 123

# %%
print(numero01)
print(nome_aluno)
# Out:
# 123
# Vinicius

# %%
34aluno = 'Vinicius'
# Out:
#   File "<ipython-input-12-522204ae5fd2>", line 1
#     34aluno = 'Vinicius'
#           ^
# SyntaxError: invalid syntax

# %%
Nome_aluno = 'Gabriel'

# %%
print(nome_aluno)
print(Nome_aluno)
# Out:
# Vinicius
# Gabriel

# %% [markdown]
# # Tipos de variáveis

# %% [markdown]
# ## Inteiros

# %%
numero_telefone = 7765438765

# %%
type(numero_telefone)
# Out:
# int

# %%
numero_cpf = 797647564

# %%
type(numero_cpf)
# Out:
# int

# %% [markdown]
# ## Floats

# %%
altura = 1.80

# %%
type(altura)
# Out:
# float

# %%
peso = 80.67

# %%
type(peso)
# Out:
# float

# %% [markdown]
# ## Strings

# %%
nome_professor = 'Vinicius'

# %%
type(nome_professor)
# Out:
# str

# %% [markdown]
# ## Booleanos

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
status = True

# %%
type(status)
# Out:
# bool

# %% [markdown]
# # Exemplos

# %%
numero01 = 1000
numero02 = 1000
numero03 = 1000

# %%
soma = numero01 + numero02 + numero03

# %%
soma
# Out:
# 3000
