# %% [markdown]
# <a href="https://colab.research.google.com/github/valmirdev/Fundamentos-da-Linguagem-Python/blob/main/Meu_primeiro_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # Título 1
#
# Meu primeiro notebook
