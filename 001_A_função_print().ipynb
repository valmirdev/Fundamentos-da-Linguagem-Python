# %% [markdown]
# <a href="https://colab.research.google.com/github/valmirdev/Fundamentos-da-Linguagem-Python/blob/main/001_A_fun%C3%A7%C3%A3o_print().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Função print()
#
# A função print() é uma das funções mais importantes e usadas na linguagem Python. Sua função é, basicamente, exibir mensagens na tela ou enviá-las para outro dispositivo, como imprimir dentro de arquivos de texto.
#
# No Python 3, print() é uma função interna, de modo que não é necessário importar nenhuma biblioteca para poder utilizá-la. Basta chamá-la e passar os argumentos necessários.

# %%
print('Meu primeiro print!')
# Out:
# Meu primeiro print!

# %%
print("Meu primeiro print!")
# Out:
# Meu primeiro print!

# %%
print("D'água")
# Out:
# D'água

# %%
print('D'água')
# Out:
#   File "<ipython-input-7-7a0cfaa784c0>", line 1
#     print('D'água')
#                 ^
# SyntaxError: invalid syntax

# %%
print(20 * 50)
print(125 * 4)
# Out:
# 1000
# 500

# %%
print(12345)
# Out:
# 12345

# %%
nome = 'Vinicius'

# %%
print(nome)
# Out:
# Vinicius

# %%
print('Vinicius', 10000, 'Python', 12 * 56)
# Out:
# Vinicius 10000 Python 672
